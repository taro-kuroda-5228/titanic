# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier 
train= pd.read_csv("../data/input/train.csv").replace("male",0).replace("female",1).replace("S",0).replace("C",1).replace("Q",2)
test= pd.read_csv("../data/input/test.csv").replace("male",0).replace("female",1).replace("S",0).replace("C",1).replace("Q",2) 
train["Age"].fillna(train.Age.mean(), inplace=True) 
train["Embarked"].fillna(train.Embarked.mean(), inplace=True) 
combine1 = [train]

for train in combine1: 
        train['Salutation'] = train.Name.str.extract(' ([A-Za-z]+).', expand=False) 
for train in combine1: 
        train['Salutation'] = train['Salutation'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
        train['Salutation'] = train['Salutation'].replace('Mlle', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Ms', 'Miss')
        train['Salutation'] = train['Salutation'].replace('Mme', 'Mrs')
        del train['Name']
Salutation_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5} 

for train in combine1: 
        train['Salutation'] = train['Salutation'].map(Salutation_mapping) 
        train['Salutation'] = train['Salutation'].fillna(0) 
    
for train in combine1: 
        train['Ticket_Lett'] = train['Ticket'].apply(lambda x: str(x)[0])
        train['Ticket_Lett'] = train['Ticket_Lett'].apply(lambda x: str(x)) 
        train['Ticket_Lett'] = np.where((train['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), train['Ticket_Lett'], np.where((train['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0')) 
        train['Ticket_Len'] = train['Ticket'].apply(lambda x: len(x)) 
        del train['Ticket'] 
train['Ticket_Lett']=train['Ticket_Lett'].replace("1",1).replace("2",2).replace("3",3).replace("0",0).replace("S",3).replace("P",0).replace("C",3).replace("A",3) 

    
for train in combine1: 
    train['Cabin_Lett'] = train['Cabin'].apply(lambda x: str(x)[0]) 
    train['Cabin_Lett'] = train['Cabin_Lett'].apply(lambda x: str(x)) 
    train['Cabin_Lett'] = np.where((train['Cabin_Lett']).isin([ 'F', 'E', 'D', 'C', 'B', 'A']),train['Cabin_Lett'], np.where((train['Cabin_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']), '0','0'))
del train['Cabin'] 
train['Cabin_Lett']=train['Cabin_Lett'].replace("A",1).replace("B",2).replace("C",1).replace("0",0).replace("D",2).replace("E",2).replace("F",1) 
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
for train in combine1:
    train['IsAlone'] = 0
    train.loc[train['FamilySize'] == 1, 'IsAlone'] = 1
train_data = train.values
xs = train_data[:, 2:] # Pclass以降の変数
y  = train_data[:, 1]  # 正解データ
test["Age"].fillna(train.Age.mean(), inplace=True)
test["Fare"].fillna(train.Fare.mean(), inplace=True)

combine = [test]
for test in combine:
    test['Salutation'] = test.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
for test in combine:
    test['Salutation'] = test['Salutation'].replace(['Lady', 'Countess','Capt', 'Col',\
         'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

    test['Salutation'] = test['Salutation'].replace('Mlle', 'Miss')
    test['Salutation'] = test['Salutation'].replace('Ms', 'Miss')
    test['Salutation'] = test['Salutation'].replace('Mme', 'Mrs')
    del test['Name']
Salutation_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}

for test in combine:
    test['Salutation'] = test['Salutation'].map(Salutation_mapping)
    test['Salutation'] = test['Salutation'].fillna(0)

for test in combine:
        test['Ticket_Lett'] = test['Ticket'].apply(lambda x: str(x)[0])
        test['Ticket_Lett'] = test['Ticket_Lett'].apply(lambda x: str(x))
        test['Ticket_Lett'] = np.where((test['Ticket_Lett']).isin(['1', '2', '3', 'S', 'P', 'C', 'A']), test['Ticket_Lett'],
                                   np.where((test['Ticket_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']),
                                            '0', '0'))
        test['Ticket_Len'] = test['Ticket'].apply(lambda x: len(x))
        del test['Ticket']
test['Ticket_Lett']=test['Ticket_Lett'].replace("1",1).replace("2",2).replace("3",3).replace("0",0).replace("S",3).replace("P",0).replace("C",3).replace("A",3) 

for test in combine:
        test['Cabin_Lett'] = test['Cabin'].apply(lambda x: str(x)[0])
        test['Cabin_Lett'] = test['Cabin_Lett'].apply(lambda x: str(x))
        test['Cabin_Lett'] = np.where((test['Cabin_Lett']).isin(['T', 'H', 'G', 'F', 'E', 'D', 'C', 'B', 'A']),test['Cabin_Lett'],
                                   np.where((test['Cabin_Lett']).isin(['W', '4', '7', '6', 'L', '5', '8']),
                                            '0','0'))        
        del test['Cabin']
test['Cabin_Lett']=test['Cabin_Lett'].replace("A",1).replace("B",2).replace("C",1).replace("0",0).replace("D",2).replace("E",2).replace("F",1).replace("G",1) 
test["FamilySize"] = train["SibSp"] + train["Parch"] + 1

for test in combine:
    test['IsAlone'] = 0
    test.loc[test['FamilySize'] == 1, 'IsAlone'] = 1
    
test_data = test.values
xs_test = test_data[:, 1:]

from sklearn.ensemble import RandomForestClassifier

random_forest=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=25, max_features='auto', max_leaf_nodes=None,
            min_samples_leaf=1, min_samples_split=15,
            min_weight_fraction_leaf=0.0, n_estimators=51, n_jobs=4,
            oob_score=False, random_state=0, verbose=0, warm_start=False)

random_forest.fit(xs, y)
Y_pred = random_forest.predict(xs_test)


import csv
with open("Predict_result_data.csv", "w") as f:
    writer = csv.writer(f, lineterminator='\n')
    writer.writerow(["PassengerId", "Survived"])
    for pid, survived in zip(test_data[:,0].astype(int), Y_pred.astype(int)):
        writer.writerow([pid, survived])

# %%
test["Survived"]=Y_pred.astype(int)
ex= pd.read_csv("Predict_result_data.csv")
test["Survived"]=ex["Survived"]
train=train.append(test, ignore_index=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Sex          1309 non-null   int64
#  4   Age          1309 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Fare         1309 non-null   float64
#  8   Embarked     1309 non-null   float64
#  9   Salutation   1309 non-null   float64
#  10  Ticket_Lett  1309 non-null   int64
#  11  Ticket_Len   1309 non-null   int64
#  12  Cabin_Lett   1309 non-null   int64
#  13  FamilySize   1309 non-null   int64
#  14  IsAlone      1309 non-null   int64
# dtypes: float64(4), int64(11)
# memory usage: 153.5 KB

# %%
train=train.iloc[:,[7,12,8,10,0,11,6,4,2,9,14,13,1,3,5]]
train_data = train.values
xs = train_data[:, 2:] # Pclass以降の変数
y  = train_data[:, 1]  # 正解データ
test_data = test.values
xs_test = test_data[:, 1:]

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(xs,y,test_size=0.008,random_state=0)

lgb_train = lgb.Dataset(np.array(X_train),np.array(y_train))
lgb_eval = lgb.Dataset(np.array(X_test),np.array(y_test),reference=lgb_train)
 

params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2'},
    'num_leaves': 200,
    'learning_rate': 0.003,
    'num_iterations':100,
    'feature_fraction': 0.52,
    'bagging_fraction': 0.79,
    'bagging_freq': 7,
    'verbose': 0
}

gbm = lgb.train(params,
                lgb_train,
                num_boost_round=5000,
                valid_sets=lgb_eval,
                early_stopping_rounds=1000)
X_pred= gbm.predict(np.array(xs_test), num_iteration=gbm.best_iteration, predict_disable_shape_check=True)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000576 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 0.594231
# Training until validation scores don't improve for 1000 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 0.59342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 0.592775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 0.592137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 0.590073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l2: 0.588258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l2: 0.587191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l2: 0.584674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l2: 0.58233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l2: 0.581361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l2: 0.580371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l2: 0.579693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l2: 0.577612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l2: 0.575691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l2: 0.574827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l2: 0.57377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l2: 0.57263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l2: 0.570492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l2: 0.568709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l2: 0.568039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l2: 0.56677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l2: 0.564959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l2: 0.564565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l2: 0.562694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l2: 0.561221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l2: 0.560253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l2: 0.559159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l2: 0.556867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l2: 0.555674
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l2: 0.55507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l2: 0.553455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l2: 0.551636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l2: 0.550362
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l2: 0.548019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l2: 0.546837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l2: 0.546348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l2: 0.545726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l2: 0.54354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l2: 0.541082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l2: 0.539299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l2: 0.537108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l2: 0.536142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l2: 0.534298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l2: 0.533745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l2: 0.531802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l2: 0.53108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l2: 0.530476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l2: 0.528842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l2: 0.527065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l2: 0.526224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l2: 0.524238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l2: 0.522261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l2: 0.521151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l2: 0.51902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
#        0.41402243, 0.3017985 , 0.41590649, 0.4253175 , 0.41402243,
#        0.41590649, 0.41402243, 0.43838481, 0.43970676, 0.41590649,
#        0.41590649, 0.41954091, 0.41402243, 0.42245032, 0.41590649,
#        0.5083085 , 0.3017985 , 0.50330161, 0.31368147, 0.41590649,
#        0.41560177, 0.41590649, 0.4117219 , 0.41387075, 0.42453798,
#        0.42556187, 0.43311462, 0.31382232, 0.43970676, 0.43969375,
#        0.41590649, 0.41590649, 0.5083085 , 0.45768675, 0.41590649,
#        0.4531277 , 0.31392584, 0.41590649, 0.52959178, 0.41590649,
#        0.41590649, 0.4655983 , 0.41261974, 0.47530726, 0.41402243,
#        0.41590649, 0.45657912, 0.43259929, 0.41590649, 0.31382232,
#        0.4868451 , 0.53253225, 0.43449342, 0.52973348, 0.42599864,
#        0.41590649, 0.41402243, 0.42453798, 0.31382232, 0.52179261,
#        0.31382232, 0.51412955, 0.41590649, 0.41402243, 0.42450265,
#        0.41590649, 0.45768675, 0.45768675, 0.41358376, 0.48055796,
#        0.41590649, 0.52579386, 0.49224715, 0.40806529, 0.41402243,
#        0.46421439, 0.46362664, 0.41402243, 0.44028958, 0.41402243,
#        0.46145108, 0.41402243, 0.43264431, 0.42763917, 0.41570862,
#        0.41402243, 0.41402243, 0.48878959, 0.54857838, 0.43311462,
#        0.42556187, 0.41590649, 0.42316759, 0.41402243, 0.43858905,
#        0.54857838, 0.42568871, 0.46758359, 0.48653531, 0.4390262 ,
#        0.46145108, 0.50785803, 0.41590649, 0.3017985 , 0.42599864,
#        0.53836915, 0.46460809, 0.4223389 , 0.41590649, 0.50330161,
#        0.49483167, 0.41402243, 0.45043694, 0.49849177, 0.41590649,
#        0.41402243, 0.50417298, 0.46589838, 0.41590649, 0.53135045,
#        0.49897734, 0.42556187, 0.41402243, 0.52251618, 0.44354276,
#        0.3017985 , 0.30148775, 0.42599864, 0.42288709, 0.41590649,
#        0.49497362, 0.41402243, 0.41590649, 0.3017985 , 0.43256643,
#        0.50123191, 0.54072148, 0.43407583, 0.41402243, 0.43195877,
#        0.50960948, 0.3017985 , 0.53277992, 0.41590649, 0.3017985 ,
#        0.5115038 , 0.41587472, 0.49886182, 0.47412556, 0.45857544,
#        0.45657912, 0.41590649, 0.52973348, 0.31382232, 0.44050341,
#        0.31382232, 0.38022519, 0.42245032, 0.41590649, 0.52810048,
#        0.41590649, 0.41402243, 0.43243224])

# %%
for i in range(418):
    if X_pred[i]>=0.51:
        X_pred[i]=1
    else:
        X_pred[i]=0

import csv
with open("Predict_result_data.csv", "w") as f:
    writer = csv.writer(f, lineterminator='\n')
    writer.writerow(["PassengerId", "Survived"])
    for pid, survived in zip(test_data[:,0].astype(int), X_pred.astype(int)):
    #for pid, survived in zip(test_data[:,0].astype(int), X_pred):
        writer.writerow([pid, survived])
